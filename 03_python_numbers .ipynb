# %% [markdown]
# <h1 style="color:purple" align="center">Python Numbers Tutorial</h1>

# %% [markdown]
# ![Python-Basics-Chapter-Numbers-in-Python_Watermarked.webp](attachment:Python-Basics-Chapter-Numbers-in-Python_Watermarked.webp)

# %%
# 1. Use python to find area of triangle
# area = (1/2)*base*height

# %%
base=15.26
print(type(base))
# Out:
# <class 'float'>

# %%
height=20.572

# %%
area= 1/2*base*height

# %%
print(area)
# Out:
# 156.96436

# %%
print("area is:",area) # area is: 105.53435999999999
# Out:
# area is: 156.96436

# %%
###### 2. basic airthmetic using numbers

# %%
print(1+2) # 3
print(1/2) # 0.5 /
10/5
# Out:
# 3
# 0.5
# 2.0

# %%
2*-5
# Out:
# -10

# %%
print(17%3) # 2
print(3**2) # 9
print(5**3)
# Out:
# 2
# 9
# 125

# %%
print(10+2*3) # 16
print((10+2)*3) # 36
# Out:
# 16
# 36

# %%
1+2*5
# Out:
# 11

# %%
(121+2) - (55-10)
# Out:
# 78

# %%
# 3. Number data types (int, float, complex numbers)

# %%
age = 20 # int

# %%
print(age)
# Out:
# 20

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
salary = 5000.66

# %%
print(salary)
# Out:
# 5000.66

# %%
print(type(salary))
# Out:
# <class 'float'>

# %%
c1=2+3j

# %%
print(c1)
# Out:
# (2+3j)

# %%
print(type(c1)) # complex
# Out:
# <class 'complex'>

# %% [markdown]
# ## 1. You have a football field that is 92 meter long and 48.8 meter wide. Find out total area using python and print it

# %% [markdown]
# ## 2. You bought 9 packets of potato chips from a store. Each packet costs 1.49 dollar
# ###    and you gave shopkeeper 20 dollar.
# ###  Find out using python, how many dollars is the shopkeeper going to give you back?
