# %% [markdown]
# <h1 style="color:purple" align="center">String Introduction</h1>

# %% [markdown]
# ![Strings-and-Character-Data-in-Python_Watermarked.webp](attachment:Strings-and-Character-Data-in-Python_Watermarked.webp)

# %% [markdown]
# ### Assign String to a Variable
# Assigning a string to a variable is done with the variable name followed
# by an equal sign and the string:

# %%
name = "mohammad ashour     "
name = 'mohammad ashour'

# %%
name2 = "ali"
name3 = "ahmed"
print(name2)
# Out:
# ali

# %%
print(name3)
# Out:
# ahmed

# %% [markdown]
# **Index Operator**

# %%
print(name)
# Out:
# mohammad ashour

# %%
print(name[0])
# Out:
# m

# %%
print(name[1])
# Out:
# o

# %%
print(name[20])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 print(name[20])
#
# IndexError: string index out of range

# %%
print(name[8])

# %% [markdown]
# **String Slicing**

# %%
print(name)
# Out:
# mohammad ashour

# %%
print(name[  0 : 8])
# Out:
# mohammad

# %%
print(name[  0 : 8  ])
# Out:
# mohammad

# %%
print(name[  0 : 3  ])
# Out:
# moh

# %%
print(name[  9 :  ])
# Out:
# ashour

# %%
print(name)
# Out:
# mohammad ashour

# %%
print(name[  3 :   ])
# Out:
# ammad ashour

# %%
print(name[   :  8 ])
# Out:
# mohammad

# %% [markdown]
# **len function**

# %%
print(len(name))
# Out:
# 15

# %%
print(len(name2))
# Out:
# 3

# %%
print(name3)
# Out:
# ahmed

# %%
print(len(name3))
# Out:
# 5

# %% [markdown]
# **in operator**

# %%
print(name)
# Out:
# mohammad ashour

# %%
'mohammad' in name
# Out:
# True

# %%
'ash' in name
# Out:
# True

# %%
't' in name
# Out:
# False

# %%
"ammad" in name
# Out:
# True

# %%
print(name)
# Out:
# mohammad ashour

# %%
name[0] = "A"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [36], in <cell line: 1>()
# ----> 1 name[0] = "A"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ![How-to-Replace-Parts-of-a-String-in-Python_Watermarked.webp](attachment:How-to-Replace-Parts-of-a-String-in-Python_Watermarked.webp)

# %% [markdown]
# **replace function**

# %%
my_name = "mohammad ashour"

# %%
print(my_name)
# Out:
# mohammad ashour

# %%
my_name = my_name.replace("mohammad" , "Ahmed" )

# %%
print(my_name)
# Out:
# Ahmed ashour

# %%
my_name
# Out:
# 'Ahmed ashour'

# %%
my_name = my_name.replace("ahemd" , "Ali").replace("ashour" , "Mostafa")

# %%
my_name
# Out:
# 'Ahmed Mostafa'

# %% [markdown]
# **upper and lower function**

# %%
my_name.upper()
# Out:
# 'AHMED MOSTAFA'

# %%
my_name.lower()
# Out:
# 'ahmed mostafa'

# %%
my_name.title()
# Out:
# 'Ahmed Mostafa'

# %%
my_name.capitalize()
# Out:
# 'Ahmed mostafa'

# %%
my_name = my_name.lower()
my_name
# Out:
# 'ahmed mostafa'

# %%
my_name.isupper()
# Out:
# False

# %%
my_name.islower()
# Out:
# True

# %% [markdown]
# **isdigit and index function**

# %%
nums = "123456"

# %%
nums.isdigit()
# Out:
# True

# %%
nums_2 = "12345mohammasd"

# %%
nums_2.isdigit()
# Out:
# False

# %%
name
# Out:
# 'mohammad ashour'

# %%
name.index('m')
# Out:
# 0

# %%
name.index("a")
# Out:
# 3

# %%
name.index("ad")
# Out:
# 6

# %%
states=29
text='total states in egypt:'
text+states
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [76], in <cell line: 3>()
#       1 states=29
#       2 text='total states in egypt:'
# ----> 3 text+states
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ## Remove Whitespace
# Whitespace is the space before and/or after the actual text, and very
# often you want to remove this space.

# %%
a = "          Hell   o, World! "
print(a)
# Out:
#           Hell   o, World!

# %%
a.strip()
# Out:
# 'Hell   o, World!'

# %% [markdown]
# ### Python String endswith() and startwith Methods

# %%
my_name = "Ahmed"
print(my_name)
# Out:
# Ahmed

# %%
my_name.endswith("d")
# Out:
# True

# %%
my_name.startswith("e")
# Out:
# False

# %%
my_name.startswith("A")
# Out:
# True

# %%
my_name.startswith("Ah")
# Out:
# True

# %% [markdown]
# **str function**

# %%
'29' + "name"
# Out:
# '29name'

# %%
str(states)
# Out:
# '29'

# %%
print(text + str(states))
# Out:
# total states in egypt:29

# %% [markdown]
# **quote or double quote inside the string**

# %%
name = "ahmed's gift"

# %%
name2 =' mohammad" mazen'
name2
# Out:
# ' mohammad" mazen'

# %%
name
# Out:
# "ahmed's gift"

# %%
text='let's learn python'
# Out:
#   Input In [93]
#     text='let's learn python'
#               ^
# SyntaxError: invalid syntax

# %%
text="let's learn python"
text
# Out:
# "let's learn python"

# %%
text='let\'s learn python'
text
# Out:
# "let's learn python"

# %% [markdown]
# **Special characters : newline and tab**

# %%
s='hey bro'
print(s)
# Out:
# hey bro

# %%
s='hey\nbr\no'
print(s)
# Out:
# hey
# br
# o

# %%
s='hey\t bro'
print(s)
# Out:
# hey	 bro

# %% [markdown]
# **split Function**

# %%
data = "my name is mohammad  + and my age is 20 + and my departement is cs"

# %%
data
# Out:
# 'my name is mohammad  + and my age is 20 + and my departement is cs'

# %%
data.split("+")
# Out:
# ['my name is mohammad  ', ' and my age is 20 ', ' and my departement is cs']

# %%
data.split(",")[0].strip()
# Out:
# 'my name is mohammad  + and my age is 20 + and my departement is cs'

# %%
data.split(",")[1].strip()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [128], in <cell line: 1>()
# ----> 1 data.split(",")[1].strip()
#
# IndexError: list index out of range

# %%
data.split(",")[2].strip()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [129], in <cell line: 1>()
# ----> 1 data.split(",")[2].strip()
#
# IndexError: list index out of range

# %%
data
# Out:
# 'my name is mohammad , and my age is 20,  and my departement is cs'

# %%
data.split()
# Out:
# ['my',
#  'name',
#  'is',
#  'mohammad',
#  '+',
#  'and',
#  'my',
#  'age',
#  'is',
#  '20',
#  '+',
#  'and',
#  'my',
#  'departement',
#  'is',
#  'cs']

# %% [markdown]
# ## Python String find() Method

# %%
my_name
# Out:
# 'Ahmed'

# %%
my_name.find("h")
# Out:
# 1

# %%
my_name.find("e")
# Out:
# 3

# %%
my_name.find("w")
# Out:
# -1

# %%
my_name.index("h")
# Out:
# 1

# %%
my_name.index("w")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [139], in <cell line: 1>()
# ----> 1 my_name.index("w")
#
# ValueError: substring not found
