# %% [markdown]
# ![multiple_inheritance.png](attachment:multiple_inheritance.png)

# %%
class A : 
    
    def say_hello(self):
        print("say hello from class A")
        
class B(A) : 
     pass 

class R(B) : 
    
    pass 


class C(B,A ) : 
    pass

# %%
obj1 = A()

# %%
obj1.say_hello()
# Out:
# say hello from class A

# %%
obj2 = B()

# %%
obj2.say_hello()
# Out:
# say hello from class A

# %%
obj3 = C()

# %%
obj3.say_hello()
# Out:
# say hello from class A
