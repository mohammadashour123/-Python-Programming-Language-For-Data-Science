# %% [markdown]
# ![How-to-Create-Python-Functions-with-Optional-Arguments_Watermarked.webp](attachment:How-to-Create-Python-Functions-with-Optional-Arguments_Watermarked.webp)

# %%
# Calculate expense sum for two lists without function
list_1 = [20,30,45]
list_2 = [45,67,34]

# %%
print(list_1)
# Out:
# [20, 30, 45]

# %%
print(list_2)
# Out:
# [45, 67, 34]

# %%
for i in list_1 : 
    print(i)
# Out:
# 20
# 30
# 45

# %%
for i in list_2 : 
    print(i)
# Out:
# 45
# 67
# 34

# %%
total=0
for item in list_1:
    total = total + item 
print("total is :",total)
# Out:
# total is : 95

# %%
total=0
for item in list_2:
    total+=item
print("total is :",total)
# Out:
# total is : 146

# %% [markdown]
# ![LearnaboutprogrammingFunctionsinPython1523299_orig.png](attachment:LearnaboutprogrammingFunctionsinPython1523299_orig.png)

# %%
def calc_total(my_list) :
    total=0
    for item in my_list:
        total+=item
    
    print("total is :",total)

# %%
calc_total(list_1)
# Out:
# total is : 95

# %%
calc_total(list_2)
# Out:
# total is : 146

# %%
list_3 = [10,20,30,54,97,34,3498,18,7412,53]

# %%
calc_total(list_3)
# Out:
# total is : 11226

# %%
def calx_total(l) :
    
    total=0
    for item in list_1:
        total+=item
    print("total is :",total)

# %% [markdown]
# ![images%20%283%29.png](attachment:images%20%283%29.png)

# %%
calx_total(list_1)
# Out:
# total is : 95

# %%
calx_total(list_2)
# Out:
# total is : 95

# %%
#print full name of someone 
first_name = input("enter your first name ")
middle_name = input("enter your middel name ")
last_name = input("enter your last name ")

print(f"your full name is {first_name} {middle_name} {last_name} ")
# Out:
# enter your first name mohammad
# enter your middel name ashour
# enter your last name elsayed
# your full name is mohammad ashour elsayed

# %%
def sum_two_numbers(n1 , n2) :
    return  print(n1 + n2)

# %%
sum_two_numbers(20,55)
# Out:
# 75

# %%
sum_two_numbers(10,-55)
# Out:
# -45

# %%
def my_friend_name(f,s):
    return print(
        f"Hello your name is {f.strip().capitalize()} {s.capitalize()}"
        )

# %%
my_friend_name(" ali  " , "mostafa ")
# Out:
# Hello your name is Ali Mostafa

# %%
#muliplay 2 positive numbers using functions and conditions : 

def mul(num1, num2 ):
    if (num1 > 0) and (num2 > 0) :
        return print(num1 * num2)
    else:
        return print("please enter positive numnbers ")

# %%
mul(2,10)
# Out:
# 20

# %%
mul(20,-5)
# Out:
# please enter positive numnbers

# %%
def say_hello_return(n1,n2,n3):
    print("hello ")
    print("hello ")
    
    return print(n1)
    print("hello ")

    return print(n2)
    return print(n3)

say_hello_return("mohammad"  , "ahmed" , "ali")
# Out:
# hello
# hello
# mohammad

# %%
def packing_function(*i):
    for item in i: 
         print(f"your name is {item}")

# %%
packing_function("mohammad" , "ashour"  , "mostafa" , "mona")
# Out:
# your name is mohammad
# your name is ashour
# your name is mostafa
# your name is mona

# %%
def user(name , age = 30 , country = "unknown"):
    print(f"yout name is {name} your age is {age} your country is {country}")

user("mohammad"   )
# Out:
# yout name is mohammad your age is 30 your country is unknown
